# %%
rdd1 = sc.parallelize([1,2,3,4,5,6,7,8],3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>[1, 2, 3, 4, 5, 6, 7, 8]
# </div>

# %%
rdd2 = rdd1.map(lambda x:x+1).filter(lambda x:x%2 == 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>[2, 4, 6, 8]
# </div>

# %%
rdd2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>PythonRDD[2] at collect at &lt;command-3365007036621993&gt;:1
# </div>

# %%
rdd1 = sc.parallelize([1,2,3,2],2)
rdd2 = sc.parallelize([3,5,6],3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd1.union(rdd2).glom().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[[1, 2], [3, 2], [3], [5], [6]]
# </div>

# %%
rdd1.intersection(rdd2).glom().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>[[], [], [], [3], []]
# </div>

# %%
rdd = sc.parallelize([('a',10),('b',2),('a',12),('b',12)],3)
rdd = rdd.map(lambda x:(x[0],x[1]+1))
rdd.reduceByKey(lambda x,y:(x,y),2).glom().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">29</span><span class="ansired">]: </span>[[(&apos;b&apos;, (3, 13))], [(&apos;a&apos;, (11, 13))]]
# </div>

# %%
rdd = sc.parallelize([("a", 1), ("b", 1), ("a", 2),("a",8),("c",4), ("a", 12),("a",18),("c",14)],2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd.glom().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">31</span><span class="ansired">]: </span>
# [[(&apos;a&apos;, 1), (&apos;b&apos;, 1), (&apos;a&apos;, 2), (&apos;a&apos;, 8)],
#  [(&apos;c&apos;, 4), (&apos;a&apos;, 12), (&apos;a&apos;, 18), (&apos;c&apos;, 14)]]
# </div>

# %%
rdd.combineByKey(lambda acc:(acc,1), 
                 lambda acc,data: (acc[0]+data, acc[1]+1), #within partition
                 lambda acc1,acc2: (acc1[0]+acc2[0], acc1[1]+acc2[1])).map(lambda x:(x[0],x[1][0]/x[1][1])).collect() #across partition
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">40</span><span class="ansired">]: </span>[(&apos;c&apos;, 9.0), (&apos;b&apos;, 1.0), (&apos;a&apos;, 8.2)]
# </div>

# %%
def mystr(d):
    print ('In MyStr')
    return (d,1)

# 2nd time & onwards for same key in same partition
def myconcat(a,b):
    print ('In MyConcat')
    return (a[0] + b,a[1]+1)

#Works across partitions
def mypartConcat(a,b):
    print ('In myPartConcat')
    return (a[0] + b[0],a[1] + b[1])

#mystr - this converts the V into of type C
data = rdd.combineByKey(mystr, myconcat, mypartConcat)
data.map(lambda x: (x[0], x[1][0]/(x[1][1]*1.0))).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">42</span><span class="ansired">]: </span>[(&apos;c&apos;, 9.0), (&apos;b&apos;, 1.0), (&apos;a&apos;, 8.2)]
# </div>

# %%
hr_data = sc.textFile('/FileStore/tables/HR_comma_sep.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hr_data.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">57</span><span class="ansired">]: </span>/FileStore/tables/HR_comma_sep.csv MapPartitionsRDD[112] at textFile at NativeMethodAccessorImpl.java:0
# </div>

# %%
hr_data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">58</span><span class="ansired">]: </span>15000
# </div>

# %%
hr_data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">59</span><span class="ansired">]: </span>15000
# </div>

# %%
hr_data.map(lambda x:x.split(',')).filter(lambda x:x[0]!='satisfaction_level').take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">49</span><span class="ansired">]: </span>
# [[&apos;0.38&apos;, &apos;0.53&apos;, &apos;2&apos;, &apos;157&apos;, &apos;3&apos;, &apos;0&apos;, &apos;1&apos;, &apos;0&apos;, &apos;sales&apos;, &apos;low&apos;],
#  [&apos;0.8&apos;, &apos;0.86&apos;, &apos;5&apos;, &apos;262&apos;, &apos;6&apos;, &apos;0&apos;, &apos;1&apos;, &apos;0&apos;, &apos;sales&apos;, &apos;medium&apos;],
#  [&apos;0.11&apos;, &apos;0.88&apos;, &apos;7&apos;, &apos;272&apos;, &apos;4&apos;, &apos;0&apos;, &apos;1&apos;, &apos;0&apos;, &apos;sales&apos;, &apos;medium&apos;]]
# </div>

# %%
spark.sparkContext.parallelize([1,2,3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">52</span><span class="ansired">]: </span>ParallelCollectionRDD[117] at parallelize at PythonRDD.scala:267
# </div>

# %%
df = spark.createDataFrame([(1,2),(3,4),(4,2),(2,3)],['A','B'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+
#   A|  B|
# +---+---+
#   1|  2|
#   3|  4|
#   4|  2|
#   2|  3|
# +---+---+
#
# </div>

# %%
df.withColumn('C',df.A+1).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+---+
#   A|  B|  C|
# +---+---+---+
#   1|  2|  2|
#   3|  4|  4|
#   4|  2|  5|
#   2|  3|  3|
# +---+---+---+
#
# </div>

# %%
hr_data = spark.read.csv('/FileStore/tables/HR_comma_sep.csv', inferSchema=True, header=True).repartition(13)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(hr_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(hr_data[(hr_data.satisfaction_level < .1) & (hr_data.number_project > 5) & (hr_data.time_spend_company > 5) & (hr_data.sales == "sales")])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>satisfaction_level</th><th>last_evaluation</th><th>number_project</th><th>average_montly_hours</th><th>time_spend_company</th><th>Work_accident</th><th>left</th><th>promotion_last_5years</th><th>sales</th><th>salary</th></tr></thead><tbody></tbody></table></div>
