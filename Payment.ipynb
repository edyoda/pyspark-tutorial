# %%
data = spark.read.csv('/FileStore/tables/payments_data-d8dd4.csv',header=True, inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Change_Type: string (nullable = true)
# -- Covered_Recipient_Type: string (nullable = true)
# -- Teaching_Hospital_CCN: integer (nullable = true)
# -- Teaching_Hospital_ID: integer (nullable = true)
# -- Teaching_Hospital_Name: string (nullable = true)
# -- Physician_Profile_ID: integer (nullable = true)
# -- Physician_First_Name: string (nullable = true)
# -- Physician_Middle_Name: string (nullable = true)
# -- Physician_Last_Name: string (nullable = true)
# -- Physician_Name_Suffix: string (nullable = true)
# -- Recipient_Primary_Business_Street_Address_Line1: string (nullable = true)
# ...

# %%
data.createOrReplaceTempView("payments")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.sql("select Physician_Profile_ID as physician_id, Date_of_Payment as date_payment, Record_ID as record_id, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name as payer, Total_Amount_of_Payment_USDollars as amount, Physician_Specialty, Nature_of_Payment_or_Transfer_of_Value as Nature_of_payment from payments ")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.createOrReplaceTempView("payments")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("select physician_specialty, count(*) as cnt, sum(amount)as total from payments group by physician_specialty order by total desc").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+------------------+
#  physician_specialty| cnt|             total|
# +--------------------+----+------------------+
# Allopathic &amp; Oste...|3961|2094694.5800000057|
# Allopathic &amp; Oste...|  72|        1365583.68|
#                 null|  97|         882143.45|
# Allopathic &amp; Oste...|6160|         209894.63|
# Allopathic &amp; Oste...|2216|203179.69999999984|
# Allopathic &amp; Oste...|  38|195464.62999999998|
# Allopathic &amp; Oste...| 146|172930.65999999997|
# Podiatric Medicin...| 294|168164.62999999983|
# Allopathic &amp; Oste...| 672|125477.00999999988|
# ...

# %%
data.write.
